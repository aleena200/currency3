# %%
import os
import pathlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import shutil
import random
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D, Activation, GlobalMaxPool2D, BatchNormalization
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import plot_model
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import splitfolders

# %%
# splits dataset it into three subfolders: train, val (validation), and test.

splitfolders.ratio(r"/home/user/AjayCurrency/Currency_Dataset", output="output",
    seed=1337, ratio=(.75, .2, .05), group_prefix=None, move=False)
# Out:
# Copying files: 600 files [00:04, 143.21 files/s]

# %%
data_dir = pathlib.Path('output/')
train_dir = 'output/train'
val_dir = 'output/val'
test_dir = 'output/test'

# %%
class_name = np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_name)
# Out:
# ['test' 'train' 'val']

# %%
for dirpath, dirnames, filenames in os.walk('output'):
  print(f"{len(dirnames)} folder and {len(filenames)} images in {dirpath}")
# Out:
# 3 folder and 0 images in output
# 6 folder and 0 images in output/train
# 0 folder and 75 images in output/train/50_new
# 0 folder and 75 images in output/train/10_new
# 0 folder and 75 images in output/train/200_new
# 0 folder and 75 images in output/train/500_new
# 0 folder and 75 images in output/train/100_new
# 0 folder and 75 images in output/train/20_new
# 6 folder and 0 images in output/test
# 0 folder and 5 images in output/test/50_new
# 0 folder and 5 images in output/test/10_new
# 0 folder and 5 images in output/test/200_new
# 0 folder and 5 images in output/test/500_new
# 0 folder and 5 images in output/test/100_new
# 0 folder and 5 images in output/test/20_new
# 6 folder and 0 images in output/val
# 0 folder and 20 images in output/val/50_new
# 0 folder and 20 images in output/val/10_new
# 0 folder and 20 images in output/val/200_new
# 0 folder and 20 images in output/val/500_new
# 0 folder and 20 images in output/val/100_new
# 0 folder and 20 images in output/val/20_new

# %%
def view_random_image(target_dir, target_class):
    target_folder = target_dir + target_class
    random_image = random.sample(os.listdir(target_folder), 1)
    img = mpimg.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")
    
    print(f"Image Shape : {img.shape}")
    plt.show()

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='10_new')
# Out:
# Image Shape : (3072, 4096, 3)

# %%
# Sets the global random seed.
tf.random.set_seed(46)

# preprocess data
train_datagen = ImageDataGenerator(rescale=1/255.0,
                                   rotation_range=0.2,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   vertical_flip=True,
                                   horizontal_flip=True)
valid_datagen = ImageDataGenerator(rescale=1/255.0)
test_datagen = ImageDataGenerator(rescale=1/255.0)

# %%
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=True,
                                               seed=46,
                                               classes=['10_new', '20_new', '50_new', '100_new', '200_new', '500_new'] )
                                                                                                                        

valid_data = valid_datagen.flow_from_directory(val_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)

test_data = test_datagen.flow_from_directory(test_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)
# Out:
# Found 450 images belonging to 6 classes.
# Found 120 images belonging to 6 classes.
# Found 30 images belonging to 6 classes.

# %%
train_data.class_indices
# Out:
# {'10_new': 0,
#  '20_new': 1,
#  '50_new': 2,
#  '100_new': 3,
#  '200_new': 4,
#  '500_new': 5}

# %%
train_y=train_data.classes
val_y=valid_data.classes
test_y=test_data.classes

# %%
print("train_y.shape: ", train_y.shape)
print("val_y.shape: ", val_y.shape)
print("test_y.shape: ", test_y.shape)
# Out:
# train_y.shape:  (450,)
# val_y.shape:  (120,)
# test_y.shape:  (30,)

# %%
base_model = tf.keras.applications.DenseNet121(input_shape=(224, 224, 3),
                                                        include_top=False,
                                                        weights='imagenet')
base_model.trainable = False

# %%
global_average_layer = GlobalAveragePooling2D()
prediction_layer = Dense(6)
softmax = Activation('softmax')

inputs = Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = Dropout(0.25)(x)
x = global_average_layer(x)
outputs = prediction_layer(x)
outputs = softmax(outputs)

model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │         6,150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 6)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,043,654 (26.87 MB)
#  Trainable params: 6,150 (24.02 KB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

# train model
history = model.fit(train_data, epochs=20, validation_data=valid_data)
# Out:
# /home/user/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 133s 16s/step - accuracy: 0.1760 - loss: 2.1028 - val_accuracy: 0.2167 - val_loss: 1.9223
# Epoch 2/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 100s 13s/step - accuracy: 0.1720 - loss: 1.9334 - val_accuracy: 0.1417 - val_loss: 1.8844
# Epoch 3/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 100s 13s/step - accuracy: 0.2729 - loss: 1.7684 - val_accuracy: 0.1417 - val_loss: 1.9633
# Epoch 4/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 100s 13s/step - accuracy: 0.3372 - loss: 1.6965 - val_accuracy: 0.1333 - val_loss: 2.0272
# Epoch 5/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 121s 16s/step - accuracy: 0.3550 - loss: 1.5647 - val_accuracy: 0.1250 - val_loss: 2.0616
# Epoch 6/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 101s 13s/step - accuracy: 0.4365 - loss: 1.4853 - val_accuracy: 0.1250 - val_loss: 2.1040
# Epoch 7/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 100s 14s/step - accuracy: 0.4467 - loss: 1.4993 - val_accuracy: 0.0750 - val_loss: 2.0864
# Epoch 8/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 101s 13s/step - accuracy: 0.5615 - loss: 1.3314 - val_accuracy: 0.1000 - val_loss: 2.1778
# Epoch 9/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 99s 12s/step - accuracy: 0.5542 - loss: 1.3046 - val_accuracy: 0.0833 - val_loss: 2.2127
# Epoch 10/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 100s 13s/step - accuracy: 0.6430 - loss: 1.2058 - val_accuracy: 0.1000 - val_loss: 2.3155
# Epoch 11/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 99s 13s/step - accuracy: 0.6077 - loss: 1.2122 - val_accuracy: 0.0583 - val_loss: 2.3079
# Epoch 12/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 100s 12s/step - accuracy: 0.6948 - loss: 1.1291 - val_accuracy: 0.0417 - val_loss: 2.3663
# Epoch 13/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 101s 13s/step - accuracy: 0.6375 - loss: 1.1296 - val_accuracy: 0.0500 - val_loss: 2.4020
# Epoch 14/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 102s 13s/step - accuracy: 0.6969 - loss: 1.0559 - val_accuracy: 0.0667 - val_loss: 2.5175
# Epoch 15/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 140s 13s/step - accuracy: 0.7329 - loss: 1.0543 - val_accuracy: 0.0583 - val_loss: 2.4829
# Epoch 16/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 101s 13s/step - accuracy: 0.7069 - loss: 1.0104 - val_accuracy: 0.0667 - val_loss: 2.5157
# Epoch 17/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 101s 13s/step - accuracy: 0.6929 - loss: 1.0152 - val_accuracy: 0.0750 - val_loss: 2.6046
# Epoch 18/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 101s 13s/step - accuracy: 0.7151 - loss: 0.9618 - val_accuracy: 0.0583 - val_loss: 2.6284
# Epoch 19/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 101s 14s/step - accuracy: 0.6638 - loss: 1.0244 - val_accuracy: 0.0250 - val_loss: 2.6430
# Epoch 20/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 103s 13s/step - accuracy: 0.7724 - loss: 0.8885 - val_accuracy: 0.0667 - val_loss: 2.6978

# %%
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(loss))

  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title("Loss Curves")
  plt.xlabel("Epochs")
  plt.legend()

  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title("Accuracy Curves")
  plt.xlabel("Epochs")
  plt.legend()

# %%
val_pred = model.predict(valid_data)
val_pred = val_pred.argmax(axis=1)
print(classification_report(val_pred, val_y))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 25s 9s/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        11
#            1       0.20      0.14      0.16        29
#            2       0.20      0.12      0.15        34
#            3       0.00      0.00      0.00        16
#            4       0.00      0.00      0.00        20
#            5       0.00      0.00      0.00        10
#
#     accuracy                           0.07       120
#    macro avg       0.07      0.04      0.05       120
# weighted avg       0.11      0.07      0.08       120

# %%
cfm_val = confusion_matrix(val_pred, val_y)
ax = sns.heatmap(cfm_val, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
test_pred = model.predict(test_data)
test_pred = test_pred.argmax(axis=1)
print(classification_report(test_pred, test_y))
# Out:
# /home/user/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.20      0.14      0.17         7
#            2       0.20      0.17      0.18         6
#            3       0.20      0.14      0.17         7
#            4       0.20      0.25      0.22         4
#            5       0.00      0.00      0.00         3
#
#     accuracy                           0.13        30
#    macro avg       0.13      0.12      0.12        30
# weighted avg       0.16      0.13      0.14        30

# %%
cfm_test = confusion_matrix(test_pred, test_y)
ax = sns.heatmap(cfm_test, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
model.save('my_model.keras')

# %%
import matplotlib.pyplot as plt
from keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk

# Define class labels
class_names = {0: '10_new', 1: '20_new', 2: '50_new', 3: '100_new', 4: '200_new',5:'500_new'}

# Load the trained model
model = load_model('my_model.keras')

def upload_image():
    file_path = filedialog.askopenfilename()
    if not file_path:
        return
    
    img = image.load_img(file_path, target_size=(224, 224))
    img_array = np.array(img) / 255.0
    img_array = img_array.reshape(1, 224, 224, 3)
    
    predictions = model.predict(img_array)
    predicted_class_index = np.argmax(predictions)
    predicted_class = class_names.get(predicted_class_index, "Unknown")
    
    print("Predicted Class:", predicted_class)
    
    img_display = Image.open(file_path)
    img_display = img_display.resize((300, 300))
    img_display = ImageTk.PhotoImage(img_display)
    panel.config(image=img_display)
    panel.image = img_display
    label.config(text=f"Predicted Class: {predicted_class}")

# Create the GUI window
root = tk.Tk()
root.title("Image Classifier")

btn = tk.Button(root, text="Upload Image", command=upload_image)
btn.pack()

panel = tk.Label(root)
panel.pack()

label = tk.Label(root, text="Predicted Class: None", font=("Arial", 14))
label.pack()

root.mainloop()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Predicted Class: 50_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Predicted Class: 20_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted Class: 20_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Predicted Class: 50_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Predicted Class: 100_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Predicted Class: 200_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Predicted Class: 100_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Predicted Class: 500_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Predicted Class: 20_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted Class: 20_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Predicted Class: 10_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Predicted Class: 50_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted Class: 10_new

# %%
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Predicted Class: 200_new with 37.50% confidence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted Class: 20_new with 44.80% confidence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted Class: 50_new with 36.84% confidence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted Class: 100_new with 79.65% confidence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Predicted Class: 500_new with 42.10% confidence

# %%
import cv2
import numpy as np
import tkinter as tk
from tkinter import Label
from keras.models import load_model
from tensorflow.keras.preprocessing import image
from PIL import Image, ImageTk

# Define class labels
class_names = {0: '10_new', 1: '20_new', 2: '50_new', 3: '100_new', 4: '200_new',5:'500_new'}

# Load the trained model
model = load_model('my_model.keras')

# Initialize the webcam
cap = cv2.VideoCapture(0)

# Function to preprocess frame and make predictions
def process_frame():
    ret, frame = cap.read()
    if not ret:
        return None, None, None
    
    # Convert the frame to grayscale for better note detection
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Use thresholding to detect edges of a note
    _, thresh = cv2.threshold(gray_frame, 200, 255, cv2.THRESH_BINARY)

    # Find contours to detect if there is a note in the frame
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Check if contours are found (indicating a note is present)
    if len(contours) == 0:
        return frame, None, None  # No note detected
    
    # Resize the frame to match the input size of the model
    img_resized = cv2.resize(frame, (224, 224))
    img_array = np.array(img_resized) / 255.0
    img_array = img_array.reshape(1, 224, 224, 3)
    
    # Make prediction
    predictions = model.predict(img_array)
    predicted_class_index = np.argmax(predictions)
    predicted_class = class_names.get(predicted_class_index, "Unknown")
    confidence = predictions[0][predicted_class_index] * 100  # Get confidence as percentage

    return frame, predicted_class, confidence

# Function to update the GUI with the camera feed
def update_frame():
    frame, predicted_class, confidence = process_frame()
    
    if frame is not None:
        # Convert frame to Image for Tkinter
        img_display = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        img_display = Image.fromarray(img_display)
        img_display = img_display.resize((300, 300))
        img_display = ImageTk.PhotoImage(img_display)

        panel.config(image=img_display)
        panel.image = img_display
        
        if predicted_class is None:
            label.config(text="Please show a note!")
        else:
            # Update prediction text
            label.config(text=f"Predicted Class: {predicted_class}\nConfidence: {confidence:.2f}%")
    
    # Repeat the function to continuously update the frame
    root.after(10, update_frame)

# Create the GUI window
root = tk.Tk()
root.title("Real-time Note Classifier")

# Add the camera feed display panel
panel = Label(root)
panel.pack()

# Add label to display predictions
label = tk.Label(root, text="Please show a note!", font=("Arial", 14))
label.pack()

# Start the real-time update
update_frame()

root.mainloop()

# Release the camera feed when the window is closed
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
train_data.class_indices
# Out:
# {'10_new': 0,
#  '20_new': 1,
#  '50_new': 2,
#  '100_new': 3,
#  '200_new': 4,
#  '500_new': 5}

# %%
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Predicted Class: 50_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Predicted Class: 20_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Predicted Class: 500_new
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Predicted Class: 200_new
